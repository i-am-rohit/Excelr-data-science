# %% [markdown]
# ## Neural Network Gas Turbine

# %%
import pandas as pd
import numpy as np
import sklearn

# %%
gt = pd.read_csv("/content/gas_turbines.csv")
gt.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %% [markdown]
# # EDA

# %%
gt.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# std       16.527806      7.866803     15.829717      1.103196      2.222206
# min     1000.800000    512.450000    100.170000      9.904400      0.000388
# 25%     1079.600000    542.170000    127.985000     11.622000      0.858055
# 50%     1088.700000    549.890000    133.780000     12.025000      1.390200
# 75%     1096.000000    550.060000    140.895000     12.578000      2.160400
# max     1100.800000    550.610000    174.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %%
gt.shape
# Out:
# (15039, 11)

# %%
gt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
gt.columns
# Out:
# Index(['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'TEY', 'CDP', 'CO',
#        'NOX'],
#       dtype='object')

# %% [markdown]
# #### Handling missing value

# %%
gt.isnull().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %% [markdown]
# #### Handling Duplicate records

# %%
# check for duplicate data
duplicate = gt.duplicated()
print(duplicate.sum())
gt[duplicate]
# Out:
# 0
# Empty DataFrame
# Columns: [AT, AP, AH, AFDP, GTEP, TIT, TAT, TEY, CDP, CO, NOX]
# Index: []

# %% [markdown]
# ### VISUALISATION

# %% [markdown]
# VISUALIZING BY BOXPLOT

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

for i in gt.columns:
    print(i)
    sns.boxplot(gt[i],color = 'green')
    plt.show()
# Out:
# AT
# AP
# AH
# AFDP
# GTEP
# TIT
# TAT
# TEY
# CDP
# CO
# NOX

# %% [markdown]
# #### Inferences: About Skewness
#
#     AH,TIT,TAT are left Skewed(negative-skewness)
#
#     CO are Right Skewed (positive-skewness)
#
#     AT,AP,NOX are normally distributed

# %%
# Boxplot of Turbine Energy Yield (TEY)
plt.boxplot(gt['TEY'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7badabd46b00>,
#   <matplotlib.lines.Line2D at 0x7badabd47ac0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7badabd47580>,
#   <matplotlib.lines.Line2D at 0x7badabd47010>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7badabd46ad0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7badabd465f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7badabd46620>],
#  'means': []}

# %%
sns.boxplot(gt['TEY'], color = 'green')
# Out:
# <Axes: >

# %%
#sns.set(rc={'figure.figsize': (20,20)})
#sns.boxplot(x="variable",y="value", data=pd.melt(gt))

# %% [markdown]
# Independent and Dependent variable

# %%
X = gt.loc[:,['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'CDP', 'CO','NOX']]
y= gt.loc[:,['TEY']]

# %% [markdown]
# ###### CROSS VALIDATION TECHNIQUE

# %%
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# %%
def baseline_model():
    model = Sequential()
    model.add(Dense(10, input_dim=10, activation='tanh'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
import keras
from sklearn.model_selection import KFold
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import InputLayer,Dense
estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=50, batch_size=100, verbose=False)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X, y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# <ipython-input-16-ae62adc6907d>:6: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=50, batch_size=100, verbose=False)
# Results: -0.19 (0.17) MSE

# %%
estimator.fit(X, y)
prediction = estimator.predict(X)
prediction
# Out:
# array([-1.1186255, -1.1442677, -1.1535674, ..., -2.068326 , -1.7974786,
#        -1.476508 ], dtype=float32)

# %% [markdown]
# ###### Train-Test Split Model Validation Technique

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
estimator.fit(X_train, y_train)
prediction = estimator.predict(X_test)

# %%
prediction
# Out:
# array([-1.2048633,  1.9454203, -0.4083474, ..., -1.6270533,  0.7736029,
#         0.5557974], dtype=float32)

# %%
X = gt.drop(columns = ['TEY'], axis = 1)
y = gt.iloc[:,7]

# %%
from sklearn.preprocessing import scale
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 42)
X_train_scaled = scale(X_train)
X_test_scaled = scale(X_test)
X_test_scaled
# Out:
# array([[ 0.82623246, -0.43954308, -0.25924569, ...,  0.10039242,
#         -0.3796304 , -0.69217007],
#        [ 0.35282087,  0.23279782,  0.80230139, ..., -1.18541222,
#          0.39149515, -1.09475442],
#        [ 0.32839008, -0.07135639,  0.25312287, ...,  0.01665304,
#         -0.00296896, -0.31891741],
#        ...,
#        [-0.74071701,  0.37687087,  0.43427425, ...,  1.77157829,
#         -1.00127821, -0.4818816 ],
#        [-0.49965786, -0.39151873,  0.64680105, ..., -0.26517949,
#         -0.48137538,  0.12808615],
#        [ 0.13151427,  0.32884652,  0.98830762, ..., -1.40331469,
#          0.13152215, -0.64456466]])

# %%
import tensorflow as tf
input_size = len(X.columns)
output_size = 1
hidden_layer_size = 50

model = tf.keras.Sequential([

                               tf.keras.layers.Dense(hidden_layer_size, input_dim = input_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                               tf.keras.layers.Dense(output_size)
                             ])

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate = 0.03)
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['MeanSquaredError'])

# %%
num_epochs = 100
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 2)
model.fit(X_train_scaled, y_train, callbacks = early_stopping, validation_split = 0.1, epochs = num_epochs, verbose = 2)
# Out:
# Epoch 1/100
# 381/381 - 2s - loss: 2964.7773 - mean_squared_error: 2964.7773 - val_loss: 171.5665 - val_mean_squared_error: 171.5665 - 2s/epoch - 5ms/step
# Epoch 2/100
# 381/381 - 1s - loss: 94.6107 - mean_squared_error: 94.6107 - val_loss: 68.6417 - val_mean_squared_error: 68.6417 - 692ms/epoch - 2ms/step
# Epoch 3/100
# 381/381 - 1s - loss: 42.0602 - mean_squared_error: 42.0602 - val_loss: 32.3778 - val_mean_squared_error: 32.3778 - 689ms/epoch - 2ms/step
# Epoch 4/100
# 381/381 - 1s - loss: 20.2375 - mean_squared_error: 20.2375 - val_loss: 18.0315 - val_mean_squared_error: 18.0315 - 683ms/epoch - 2ms/step
# Epoch 5/100
# 381/381 - 1s - loss: 10.1693 - mean_squared_error: 10.1693 - val_loss: 7.5913 - val_mean_squared_error: 7.5913 - 811ms/epoch - 2ms/step
# Epoch 6/100
# 381/381 - 1s - loss: 5.9067 - mean_squared_error: 5.9067 - val_loss: 4.4815 - val_mean_squared_error: 4.4815 - 1s/epoch - 3ms/step
# Epoch 7/100
# 381/381 - 1s - loss: 4.1079 - mean_squared_error: 4.1079 - val_loss: 3.1365 - val_mean_squared_error: 3.1365 - 1s/epoch - 3ms/step
# Epoch 8/100
# 381/381 - 1s - loss: 2.7582 - mean_squared_error: 2.7582 - val_loss: 2.1399 - val_mean_squared_error: 2.1399 - 760ms/epoch - 2ms/step
# Epoch 9/100
# 381/381 - 1s - loss: 2.1449 - mean_squared_error: 2.1449 - val_loss: 1.5809 - val_mean_squared_error: 1.5809 - 692ms/epoch - 2ms/step
# Epoch 10/100
# 381/381 - 1s - loss: 1.6389 - mean_squared_error: 1.6389 - val_loss: 1.3268 - val_mean_squared_error: 1.3268 - 708ms/epoch - 2ms/step
# Epoch 11/100
# 381/381 - 1s - loss: 1.4872 - mean_squared_error: 1.4872 - val_loss: 1.8666 - val_mean_squared_error: 1.8666 - 696ms/epoch - 2ms/step
# Epoch 12/100
# 381/381 - 1s - loss: 1.4765 - mean_squared_error: 1.4765 - val_loss: 1.0065 - val_mean_squared_error: 1.0065 - 675ms/epoch - 2ms/step
# Epoch 13/100
# 381/381 - 1s - loss: 1.1988 - mean_squared_error: 1.1988 - val_loss: 0.9206 - val_mean_squared_error: 0.9206 - 710ms/epoch - 2ms/step
# Epoch 14/100
# 381/381 - 1s - loss: 1.0186 - mean_squared_error: 1.0186 - val_loss: 2.1422 - val_mean_squared_error: 2.1422 - 707ms/epoch - 2ms/step
# Epoch 15/100
# 381/381 - 1s - loss: 1.0401 - mean_squared_error: 1.0401 - val_loss: 0.9063 - val_mean_squared_error: 0.9063 - 679ms/epoch - 2ms/step
# Epoch 16/100
# 381/381 - 1s - loss: 0.9380 - mean_squared_error: 0.9380 - val_loss: 0.8899 - val_mean_squared_error: 0.8899 - 727ms/epoch - 2ms/step
# Epoch 17/100
# 381/381 - 1s - loss: 0.9748 - mean_squared_error: 0.9748 - val_loss: 1.7592 - val_mean_squared_error: 1.7592 - 696ms/epoch - 2ms/step
# Epoch 18/100
# 381/381 - 1s - loss: 1.0441 - mean_squared_error: 1.0441 - val_loss: 0.6958 - val_mean_squared_error: 0.6958 - 685ms/epoch - 2ms/step
# Epoch 19/100
# 381/381 - 1s - loss: 0.9287 - mean_squared_error: 0.9287 - val_loss: 0.6960 - val_mean_squared_error: 0.6960 - 676ms/epoch - 2ms/step
# Epoch 20/100
# 381/381 - 1s - loss: 0.7651 - mean_squared_error: 0.7651 - val_loss: 0.5345 - val_mean_squared_error: 0.5345 - 685ms/epoch - 2ms/step
# Epoch 21/100
# 381/381 - 1s - loss: 0.8225 - mean_squared_error: 0.8225 - val_loss: 1.2458 - val_mean_squared_error: 1.2458 - 682ms/epoch - 2ms/step
# Epoch 22/100
# 381/381 - 1s - loss: 0.9205 - mean_squared_error: 0.9205 - val_loss: 1.0544 - val_mean_squared_error: 1.0544 - 836ms/epoch - 2ms/step

# %%
test_loss, mean_squared_error = model.evaluate(X_test_scaled, y_test)
# Out:
# 47/47 [==============================] - 0s 2ms/step - loss: 0.9625 - mean_squared_error: 0.9625

# %%
predictions = model.predict_on_batch(X_test_scaled)

# %%
plt.scatter(y_test, predictions)

# %%
predictions_df = pd.DataFrame()
predictions_df['Actual'] = y_test
predictions_df['Predicted'] = predictions
predictions_df['% Error'] = abs(predictions_df['Actual'] - predictions_df['Predicted'])/predictions_df['Actual']*100
predictions_df.reset_index(drop = True)
# Out:
#       Actual   Predicted   % Error
# 0     134.46  135.658859  0.891610
# 1     111.88  113.277092  1.248741
# 2     133.72  135.109833  1.039360
# 3     133.79  134.565613  0.579724
# 4     110.77  112.307152  1.387697
# ...      ...         ...       ...
# 1499  132.85  133.620438  0.579930
# 1500  125.07  125.436890  0.293347
# 1501  160.95  161.380768  0.267641
# 1502  133.12  133.702576  0.437632
# 1503  111.79  112.979118  1.063707
#
# [1504 rows x 3 columns]

# %% [markdown]
# Results:
#
#     Here we got the information about skweness and normally distributed using Boxplot of given dataset.
#
#     By using TensorFlow, Prediction of Turbine Energy Yield (TEY) we can see error is going to decrease it means we got
#     better model.
